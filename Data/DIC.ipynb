# %%
import random

def generate_hex_randoms(num_randoms, file_path):
    with open(file_path, 'w') as file:
        for _ in range(num_randoms):
            hex_number = format(random.randint(0, 255), '02x') # 生成 0 到 255 之间的随机数，并将其格式化为两位的十六进制数字
            file.write(hex_number + '\n')

if __name__ == "__main__":
    num_randoms = 64
    for i in range(100):
        file_path = f"DIC_Data/random_hex{i+1}.txt"
        generate_hex_randoms(num_randoms, file_path)
        print(f"{num_randoms} 個十六進位隨機數字已經寫入到 {file_path} 文件中。")
# Out:
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex1.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex2.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex3.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex4.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex5.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex6.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex7.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex8.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex9.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex10.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex11.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex12.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex13.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex14.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex15.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex16.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex17.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex18.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex19.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex20.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex21.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex22.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex23.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex24.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex25.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex26.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex27.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex28.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex29.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex30.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex31.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex32.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex33.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex34.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex35.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex36.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex37.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex38.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex39.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex40.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex41.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex42.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex43.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex44.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex45.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex46.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex47.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex48.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex49.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex50.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex51.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex52.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex53.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex54.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex55.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex56.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex57.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex58.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex59.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex60.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex61.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex62.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex63.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex64.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex65.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex66.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex67.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex68.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex69.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex70.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex71.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex72.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex73.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex74.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex75.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex76.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex77.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex78.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex79.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex80.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex81.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex82.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex83.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex84.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex85.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex86.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex87.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex88.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex89.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex90.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex91.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex92.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex93.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex94.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex95.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex96.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex97.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex98.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex99.txt 文件中。
# 64 个十六进制随机数已经写入到 DIC_Data/random_hex100.txt 文件中。
